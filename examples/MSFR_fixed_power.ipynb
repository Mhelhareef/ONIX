# %%
import openmc
openmc.config['cross_sections'] = '/home/elhareefmh/MC/endfb-viii.0-hdf5/cross_sections.xml'
import onix

# %%
fuel = openmc.Material(temperature=973.15)
fuel.set_density('g/cm3', 4.1249)
fuel.add_nuclide('Li6', 1.4486e-05, 'ao')
fuel.add_nuclide('Li7', 0.28970514, 'ao')
fuel.add_nuclide('Th232', 0.07471028, 'ao')
fuel.add_nuclide('U233', 0.009401869, 'ao')
fuel.add_nuclide('F19', 0.626168224, 'ao')

fertile = openmc.Material(temperature=973.15)
fertile.set_density('g/cm3', 4.1249)
fertile.add_nuclide('Li6', 1.4486e-05, 'ao')
fertile.add_nuclide('Li7', 0.28970514, 'ao')
fertile.add_nuclide('Th232', 0.08411214953, 'ao')
fertile.add_nuclide('F19', 0.6261682243, 'ao')

b4c = openmc.Material(temperature=973.15)
b4c.set_density('g/cm3', 2.52)
b4c.add_nuclide('C12', 0.19778, 'ao')
b4c.add_nuclide('C13', 0.00222, 'ao')
b4c.add_nuclide('B10', 0.1584, 'ao')
b4c.add_nuclide('B11', 0.6416, 'ao')

reflector = openmc.Material(temperature=973.15)
reflector.set_density('g/cm3', 10)
reflector.add_element('Ni', 0.79432, 'ao')
reflector.add_element('W', 0.09976, 'ao')
reflector.add_element('Cr', 0.08014, 'ao')
reflector.add_element('Mo', 0.00736, 'ao')
reflector.add_element('Fe', 0.00632, 'ao')
reflector.add_element('Ti', 0.00295, 'ao')
reflector.add_element('C', 0.00294, 'ao')
reflector.add_element('Mn', 0.00257, 'ao')
reflector.add_element('Si', 0.00252, 'ao')
reflector.add_element('Al', 0.00052, 'ao')
reflector.add_element('B', 0.00033, 'ao')
reflector.add_element('P', 0.00023, 'ao')
reflector.add_element('S', 0.00003, 'ao')

gas = openmc.Material(temperature=973.15)
gas.set_density('g/cm3', 1.0)
gas.add_nuclide('He4', 1, 'ao')

materials = openmc.Materials([fuel, fertile, b4c, reflector, gas])
materials.cross_sections = '/home/elhareefmh/MC/endfb-viii.0-hdf5/cross_sections.xml'

s1 = openmc.ZCylinder(r=112.75)
s2 = openmc.ZCylinder(r=114.75)
s3 = openmc.ZCylinder(r=160.75)
s4 = openmc.ZCylinder(r=162.75)
s5 = openmc.ZCylinder(r=182.75)
s6 = openmc.ZCylinder(r=206.45)
s7 = openmc.ZCylinder(r=226.45)

h1 = openmc.ZPlane(z0=0.0)
h2 = openmc.ZPlane(z0=100.0)
h3 = openmc.ZPlane(z0=118.75)
h4 = openmc.ZPlane(z0=120.75)
h5 = openmc.ZPlane(z0=304.75)
h6 = openmc.ZPlane(z0=306.75)
h7 = openmc.ZPlane(z0=325.5)
h8 = openmc.ZPlane(z0=425.5)
h9 = openmc.ZPlane(z0=425.7483)

core_region = -s1 & +h2 & -h7
loop_region = -s6 & +h2 & -h7 & ~ ( -s5 & +h3 & -h6)
blanket_region = -s3 & +s2 & +h4 & -h5
struct_region = -s4 & +s1 & +h3 & -h6 & ~ blanket_region
protector_region = -s5 & +s4 & +h3 & - h6
reflector_region = -s7 & +h1 & -h8 & ~ (-s6 & +h2 & -h7)
reprocessing_region = -s7 & +h8 & -h9


s7.boundary_type = 'vacuum'
h1.boundary_type = 'vacuum'
h8.boundary_type = 'vacuum'

cell1 = openmc.Cell(name = 'core', region=core_region, fill=fuel)
cell2 = openmc.Cell(name = 'loop', region=loop_region, fill=fuel)
cell3 = openmc.Cell(name = 'blanket', region=blanket_region, fill=fertile)
cell4 = openmc.Cell(region=struct_region, fill=reflector)
cell5 = openmc.Cell(region=protector_region, fill=b4c)
cell6= openmc.Cell(region=reflector_region, fill=reflector)
cell7= openmc.Cell(name = 'reprocessing_plant',region=reprocessing_region, fill=fuel)

geo_universe = openmc.Universe()
geo_universe.add_cells([cell1, cell2, cell3, cell4, cell5, cell6, cell7])

# Create root Cell
root_cell = openmc.Cell(name='root cell')
root_cell.fill = geo_universe
root_cell.region = -s7 & +h1 & -h9

# Create root Universe
root_universe = openmc.Universe(universe_id=0, name='root universe')
root_universe.add_cell(root_cell)

root_universe.plot(width=(500, 500), pixels=40000, basis='xz', color_by='material')
root_universe.plot(color_by='material')

geometry = openmc.Geometry(root=root_universe)

# %%
settings = openmc.Settings()
settings.run_mode='eigenvalue'
space = openmc.stats.Point((0.0, 0.0, 212.75))
source = openmc.IndependentSource(space=space)
settings.source = source
settings.batches = 80
settings.inactive = 40
settings.particles = 1000

settings.temperature['method'] = 'interpolation'
settings.temperature['tolerance'] = 100.0
settings.temperature['multipole'] = True

settings.export_to_xml()
geometry.export_to_xml()
materials.export_to_xml()
openmc.run()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.2
#      Commit Hash | e23760b0264c66fb7bb373aa0596801e5209d920
#        Date/Time | 2026-02-06 14:29:25
#    MPI Processes | 1
#   OpenMP Threads | 24
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading Li6 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/Li6.h5
#  Reading Li7 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/Li7.h5
#  Reading Th232 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/Th232.h5
#  Reading U233 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/U233.h5
#  Reading F19 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/F19.h5
#  Reading C12 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/C12.h5
#  Reading C13 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/C13.h5
#  Reading B10 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/B10.h5
#  Reading B11 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/B11.h5
#  Reading Ni58 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/Ni58.h5
#  Reading Ni60 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/Ni60.h5
#  Reading Ni61 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/Ni61.h5
#  Reading Ni62 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/Ni62.h5
#  Reading Ni64 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/Ni64.h5
#  Reading W180 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/W180.h5
#  Reading W182 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/W182.h5
#  Reading W183 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/W183.h5
#  Reading W184 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/W184.h5
#  Reading W186 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/W186.h5
#  Reading Cr50 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/Cr50.h5
#  Reading Cr52 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/Cr52.h5
#  Reading Cr53 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/Cr53.h5
#  Reading Cr54 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/Cr54.h5
#  Reading Mo92 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/Mo92.h5
#  Reading Mo94 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/Mo94.h5
#  Reading Mo95 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/Mo95.h5
#  Reading Mo96 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/Mo96.h5
#  Reading Mo97 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/Mo97.h5
#  Reading Mo98 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/Mo98.h5
#  Reading Mo100 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/Mo100.h5
#  Reading Fe54 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/Fe54.h5
#  Reading Fe56 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/Fe56.h5
#  Reading Fe57 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/Fe57.h5
#  Reading Fe58 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/Fe58.h5
#  Reading Ti46 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/Ti46.h5
#  Reading Ti47 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/Ti47.h5
#  Reading Ti48 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/Ti48.h5
#  Reading Ti49 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/Ti49.h5
#  Reading Ti50 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/Ti50.h5
#  Reading Mn55 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/Mn55.h5
#  Reading Si28 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/Si28.h5
#  Reading Si29 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/Si29.h5
#  Reading Si30 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/Si30.h5
#  Reading Al27 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/Al27.h5
#  Reading P31 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/P31.h5
#  Reading S32 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/S32.h5
#  Reading S33 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/S33.h5
#  Reading S34 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/S34.h5
#  Reading S36 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/S36.h5
#  Reading He4 from /home/elhareefmh/MC/endfb-viii.0-hdf5/neutron/He4.h5
#  Minimum neutron data temperature: 250 K
#  Maximum neutron data temperature: 2500 K
#  WARNING: Windowed multipole functionality is turned on, but no multipole
#           libraries were found. Make sure that windowed multipole data is
#           present in your cross_sections.xml file.
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for Li6
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.13267
#         2/1    1.00102
#         3/1    1.11033
#         4/1    1.04858
#         5/1    1.13047
#         6/1    0.99231
#         7/1    1.03163
#         8/1    1.08563
#         9/1    1.00028
#        10/1    1.04748
#        11/1    0.98086
#        12/1    1.06308
#        13/1    1.02361
#        14/1    1.06647
#        15/1    1.00638
#        16/1    1.04779
#        17/1    1.04297
#        18/1    1.01064
#        19/1    1.01546
#        20/1    0.94852
#        21/1    1.01756
#        22/1    0.96503
#        23/1    1.00538
#        24/1    0.99449
#        25/1    0.95960
#        26/1    0.99687
#        27/1    1.03064
#        28/1    0.93888
#        29/1    1.04924
#        30/1    0.97954
#        31/1    1.00675
#        32/1    1.00510
#        33/1    1.01871
#        34/1    0.99275
#        35/1    0.98815
#        36/1    0.97502
#        37/1    1.03633
#        38/1    0.94306
#        39/1    0.96465
#        40/1    1.00591
#        41/1    0.99664
#        42/1    1.03197    1.01430 +/- 0.01767
#        43/1    0.98104    1.00322 +/- 0.01506
#        44/1    0.94350    0.98829 +/- 0.01834
#        45/1    1.01260    0.99315 +/- 0.01501
#        46/1    0.99099    0.99279 +/- 0.01226
#        47/1    1.07294    1.00424 +/- 0.01544
#        48/1    0.98035    1.00125 +/- 0.01370
#        49/1    1.00922    1.00214 +/- 0.01212
#        50/1    0.99936    1.00186 +/- 0.01084
#        51/1    0.99868    1.00157 +/- 0.00981
#        52/1    0.97459    0.99932 +/- 0.00924
#        53/1    1.03896    1.00237 +/- 0.00903
#        54/1    0.95656    0.99910 +/- 0.00897
#        55/1    1.02881    1.00108 +/- 0.00859
#        56/1    0.97761    0.99961 +/- 0.00816
#        57/1    0.97603    0.99823 +/- 0.00779
#        58/1    1.02842    0.99990 +/- 0.00754
#        59/1    0.97886    0.99880 +/- 0.00721
#        60/1    1.01367    0.99954 +/- 0.00688
#        61/1    1.03810    1.00138 +/- 0.00680
#        62/1    0.96307    0.99964 +/- 0.00671
#        63/1    0.97865    0.99872 +/- 0.00648
#        64/1    0.93405    0.99603 +/- 0.00676
#        65/1    0.99056    0.99581 +/- 0.00649
#        66/1    1.01409    0.99651 +/- 0.00628
#        67/1    0.98113    0.99594 +/- 0.00607
#        68/1    1.02215    0.99688 +/- 0.00592
#        69/1    1.04032    0.99838 +/- 0.00591
#        70/1    1.01287    0.99886 +/- 0.00573
#        71/1    0.97246    0.99801 +/- 0.00560
#        72/1    1.07962    1.00056 +/- 0.00599
#        73/1    1.04130    1.00179 +/- 0.00594
#        74/1    0.97546    1.00102 +/- 0.00581
#        75/1    1.01755    1.00149 +/- 0.00567
#        76/1    0.98748    1.00110 +/- 0.00552
#        77/1    1.04343    1.00225 +/- 0.00549
#        78/1    1.01390    1.00255 +/- 0.00535
#        79/1    0.98183    1.00202 +/- 0.00524
#        80/1    1.00324    1.00205 +/- 0.00511
#  Creating state point statepoint.80.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 2.2617e+00 seconds
#    Reading cross sections          = 2.2458e+00 seconds
#  Total time in simulation          = 3.5909e-01 seconds
#    Time in transport only          = 3.5117e-01 seconds
#    Time in inactive batches        = 1.7474e-01 seconds
#    Time in active batches          = 1.8435e-01 seconds
#    Time synchronizing fission bank = 3.7408e-03 seconds
#      Sampling source sites         = 3.2990e-03 seconds
#      SEND/RECV source sites        = 3.5031e-04 seconds
#    Time accumulating tallies       = 1.6025e-05 seconds
#    Time writing statepoints        = 2.4642e-03 seconds
#  Total time for finalization       = 5.9300e-07 seconds
#  Total time elapsed                = 2.6322e+00 seconds
#  Calculation Rate (inactive)       = 228910 particles/second
#  Calculation Rate (active)         = 216984 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.00205 +/- 0.00459
#  k-effective (Track-length)  = 1.00205 +/- 0.00511
#  k-effective (Absorption)    = 1.00433 +/- 0.00622
#  Combined k-effective        = 1.00272 +/- 0.00392
#  Leakage Fraction            = 0.00003 +/- 0.00002

# %%
import math
macrostep_vector = [1e-6, 1e-4, 1e-2, 0.5, 1, 3, 5, 10, 20, 30, 40, 50, 60, 75] 
macrostep_unit = 'y'

norma_vector = [43.7650]*len(macrostep_vector) #kW/l
norma_unit = 'power'

periods = [macrostep_vector[i] - macrostep_vector[i-1] if i>0 else macrostep_vector[i] for i in range(len(macrostep_vector))]
microstep_vector = [math.ceil(period) for period in periods]

sequence1 = onix.Sequence(1)
sequence1.set_macrostep(macrostep_vector, macrostep_unit)
sequence1.set_norma(norma_vector, norma_unit)
sequence1.microstep_vector = microstep_vector

sequence1.flux_approximation ='iv'

msr = onix.couple.Couple_msr()

msr.set_bounding_box([-226.45, -226.45, 0.0], [226.45, 226.45, 425.5])

loop_dict = {
             'core': {
                      'upstream_cells': [('loop', 1)],
                      'elements_removal': [('H', 0.0231), ('He', 0.0231), ('N', 0.0231), ('O', 0.0231), 
                                            ('Ne', 0.0231), ('Ar', 0.0231), ('Kr', 0.0231), ('Nb', 0.0231), 
                                            ('Mo', 0.0231), ('Tc', 0.0231), ('Ru', 0.0231), ('Rh', 0.0231), 
                                            ('Pd', 0.0231), ('Ag', 0.0231), ('Sb', 0.0231), ('Te', 0.0231), 
                                            ('Xe', 0.0231), ('Rn', 0.0231)
                                            ] 
             },
             'loop': {
                     'upstream_cells': [('core',0.99999989711), ('reprocessing_plant',1.0289e-07)]
             },
             'reprocessing_plant': {
                     'upstream_cells': [('core',1.0289e-07)],
                     'elements_removal': [('Zn', 1.1574e-04), ('Ga', 1.1574e-04), ('Ge', 1.1574e-04), ('As', 1.1574e-04), 
                                            ('Se', 1.1574e-04), ('Br', 1.1574e-04), ('Rb', 1.1574e-04), ('Sr', 1.1574e-04), 
                                            ('Y', 1.1574e-04), ('Zr', 1.1574e-04), ('Cd', 1.1574e-04), ('In', 1.1574e-04), 
                                            ('Sn', 1.1574e-04), ('I', 1.1574e-04), ('Cs', 1.1574e-04), ('Ba', 1.1574e-04), 
                                            ('La', 1.1574e-04), ('Ce', 1.1574e-04), ('Pr', 1.1574e-04), ('Nd', 1.1574e-04), 
                                            ('Pm', 1.1574e-04), ('Sm', 1.1574e-04), ('Eu', 1.1574e-04), ('Gd', 1.1574e-04), 
                                            ('Tb', 1.1574e-04), ('Dy', 1.1574e-04), ('Ho', 1.1574e-04), ('Er', 1.1574e-04), 
                                            ('Tm', 1.1574e-04), ('Yb', 1.1574e-04)
                                            ],
             },
            'blanket':{
                    'elements_removal': [('H', 0.0231), ('He', 0.0231), ('N', 0.0231), ('O', 0.0231), 
                                            ('Ne', 0.0231), ('Ar', 0.0231), ('Kr', 0.0231), ('Nb', 0.0231), 
                                            ('Mo', 0.0231), ('Tc', 0.0231), ('Ru', 0.0231), ('Rh', 0.0231), 
                                            ('Pd', 0.0231), ('Ag', 0.0231), ('Sb', 0.0231), ('Te', 0.0231), 
                                            ('Xe', 0.0231), ('Rn', 0.0231),   #Nobel gases 
                                            ('Zn', 6.3197e-10), ('Ga', 6.3197e-10), ('Ge', 6.3197e-10), ('As', 6.3197e-10), 
                                            ('Se', 6.3197e-10), ('Br', 6.3197e-10), ('Rb', 6.3197e-10), ('Sr', 6.3197e-10), 
                                            ('Y', 6.3197e-10), ('Zr', 6.3197e-10), ('Cd', 6.3197e-10), ('In', 6.3197e-10), 
                                            ('Sn', 6.3197e-10), ('I', 6.3197e-10), ('Cs', 6.3197e-10), ('Ba', 6.3197e-10), 
                                            ('La', 6.3197e-10), ('Ce', 6.3197e-10), ('Pr', 6.3197e-10), ('Nd', 6.3197e-10), 
                                            ('Pm', 6.3197e-10), ('Sm', 6.3197e-10), ('Eu', 6.3197e-10), ('Gd', 6.3197e-10), 
                                            ('Tb', 6.3197e-10), ('Dy', 6.3197e-10), ('Ho', 6.3197e-10), ('Er', 6.3197e-10), 
                                            ('Tm', 6.3197e-10), ('Yb', 6.3197e-10),
                                            ('U', 6.3197e-08), ('Np', 6.3197e-08), 
                                            ('Pu', 6.3197e-08), ('Am', 6.3197e-08), ('Cm', 6.3197e-08), ('Bk', 6.3197e-08), 
                                            ('Cf', 6.3197e-08), ('Es', 6.3197e-08), ('Fm', 6.3197e-08), ('Md', 6.3197e-08), 
                                            ('No', 6.3197e-08), ('Lr', 6.3197e-08)
                                            ],
                
                    'recycling': ('core', [('U', 6.3197e-08), ('Np', 6.3197e-08), 
                                            ('Pu', 6.3197e-08), ('Am', 6.3197e-08), ('Cm', 6.3197e-08), ('Bk', 6.3197e-08), 
                                            ('Cf', 6.3197e-08), ('Es', 6.3197e-08), ('Fm', 6.3197e-08), ('Md', 6.3197e-08), 
                                            ('No', 6.3197e-08), ('Lr', 6.3197e-08)
                                            ])
                        }
}
msr.vol_flow_rate = 4.5e6

msr.select_bucells(loop_dict = loop_dict)

msr.import_openmc(root_cell)

msr.set_sequence(sequence1)

vol_dict = {'core': 9005949.76, 'loop': 8.9715e+06, 'reprocessing_plant':40E3, 'blanket':7.3257e+06, 'total volume':6.8548e+07}
msr.set_vol(vol_dict)




msr.burn()
